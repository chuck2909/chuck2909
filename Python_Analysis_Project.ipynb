# %% [markdown]
# <a href="https://colab.research.google.com/github/chuck2909/chuck2909/blob/main/Python_Analysis_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Policy Patterns:**
# #**Understanding Congressional Responses to Mexican Cartel Activities**
#
# **Introduction**
#
# The operations of Mexican drug cartels, notorious for their extensive trafficking networks, not only disrupt domestic tranquility but also influence U.S. policy-making and international relations. "Policy Patterns" embarks on a meticulous examination of U.S. policy discussions, homing in on the federal response to the scourge of drug trafficking attributed to these powerful cartels.
#
# Central to this research is a thorough examination of U.S. congressional transcripts spanning the past twenty years. These documents serve as a lens, capturing the dynamic progression of political discussions, the subtleties of conversation, and the deliberate policy formulation conducted to address the complications arising from cartel operations. This study endeavors to decode the evolution of congressional rhetoric, offering a detailed perspective on the shifts in U.S. policy toward Mexican cartels.
#
# The objectives of this inquiry are twofold: firstly, to identify and analyze changes in the language, priorities, and perspectives within congressional discussions over time, and secondly, to categorize and decode the predominant themes and strategies—ranging from law enforcement and public health to international cooperation and socioeconomic measures—that emerge from these discussions.
#
# Guided by targeted research questions, the study seeks to determine how the tone and content of U.S. congressional discourse on Mexican cartel activities have evolved and what key themes and policy approaches are prevalent. Furthermore, it explores how changes in U.S. domestic and foreign policy align with these shifts in legislative dialogue.
#
# The underlying hypothesis posits a significant transformation in the congressional narrative: a move away from a narrative dominated by law enforcement and security towards an integrated approach that encompasses public health and socioeconomic considerations, reflecting broader changes in international drug policy trends.
#
# By setting forth clear research questions, outlining precise objectives, and proposing a grounded hypothesis, this analysis aims to contribute meaningfully to the understanding of policy formulation and adaptation in the face of the evolving global drug trafficking landscape. The study's structured approach promises to shed light on the strategic underpinnings that shape U.S. policy-making in this critical arena.

# %% [markdown]
# # **Research Questions**
# How has the tone and content of U.S. congressional discourse regarding Mexican cartel drug trafficking evolved across different legislative sessions?
#
#
# What key themes and policy approaches are prevalent in congressional discussions about Mexican cartels and drug trafficking?
#
#
# How do changes in U.S. domestic and foreign policy align with the shifts in congressional discourse on Mexican drug cartels?

# %% [markdown]
# # **Objectives**
#
# To identify and analyze shifts in language, priorities, and perspectives in congressional discussions over time.
# What key themes and policy approaches are prevalent in congressional discussions about Mexican cartels and drug trafficking?
#
# To categorize and understand the predominant themes and strategies discussed in congress, such as law enforcement, public health, international cooperation, or socioeconomic considerations.

# %% [markdown]
# # **Hypothesis**
#
#
#
#
# The discourse in U.S. congressional sessions regarding Mexican cartel drug trafficking has transitioned from a predominantly law enforcement and security-centric approach to a more integrated perspective that includes public health and socioeconomic considerations, reflecting broader changes in international drug policy trends.

# %% [markdown]
# # **Methods**
#
# # **Data Collection**
#
# The cornerstone of this research is the collection of official transcripts from U.S. congressional sessions, which are public records that provide verbatim accounts of discussions, debates, and policy deliberations related to Mexican cartels and drug trafficking issues.
#
# Source and Selection Criteria:
# These transcripts were sourced from the official U.S. Congress website, which maintains a comprehensive digital archive. The selection was based on keywords relevant to the study, such as “cartel,” “drug trafficking,” and “border security,” and encompassed sessions over the past two decades, to capture the evolution of discourse.
#
# There was an abundance of documents, so I changed the filter to relvancy to get the transricpts most relevant to my project and filtered for the following years 2007-2023. Link:
#
# https://www.congress.gov/quick-search/legislation?wordsPhrases=Mexican+cartels+drug+trafficking&include=on&wordVariants=on&caseSensitive=on&congressGroups%5B0%5D=0&congresses%5B0%5D=all&legislationNumbers=&legislativeAction=&sponsor=on&representative=&senator=&pageSort=relevancy&id=106942

# %% [markdown]
# # **Results From Sentiment Analysis**
#
#
#
#
# ## **Sentiment analysis over time:**
#
# The sentiment analysis, which spanned over a period from 2008 to 2022, revealed a notable shift in the tonality of the congressional discourse:
#
# From 2008 to around 2016, there was a declining trend in the average sentiment scores, indicating an increasingly negative tone in the discussions. This period may correlate with intensified cartel activities and the U.S. government's corresponding security-focused responses.
#
# Around 2016 to 2018, the sentiment reached its most negative point, possibly reflecting critical developments in drug trafficking incidents or policy setbacks.
#
# Post-2018, there was a sharp upturn in sentiment, suggesting a more positive tone in the legislative discussions. This could be indicative of a policy shift towards more comprehensive strategies or a response to positive developments in the fight against drug trafficking.
#
#
# Based on these results I asked myslef a few questions:
# What caused the fluctuations?
# One must consider what events or policy changes might correlate with these changes in sentiment.
#
# Is the sentiment score consistently calculated?
#
# Are there any external factors, such as major political events, changes in government, or significant incidents related to drug trafficking, that could explain these trends?
#
# I also have to consider the limitations of sentiment analysis tools, which may not always capture the complexities of political language and may misinterpret sarcasm, irony, or technical jargon.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Sentiment Score Distribution:**
#
# The distribution of sentiment scores represented a   concentration of scores at both extremes of the sentiment spectrum:
#
# A significant number of sessions had a highly negative sentiment (scores around -1), hinting at sessions potentially filled with critical discussions on pressing issues related to drug trafficking.
# Conversely, there was a substantial clustering of scores at the positive end (scores around +1), indicating sessions that may have discussed successful interventions, cooperative achievements, or other positive outcomes.
#
# Similar to before I have the similar questions and concerns.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **RESULTS From Topic Modeling**
#
#
# The topic modeling analysis conducted on the U.S. congressional transcripts has surfaced several dominant topics, each characterized by a set of keywords that reflect the core subject matter of the discussions. The results suggest the presence of specific themes that are consistently revisited across different legislative sessions.
#
# The topics with the highest level of contribution per document are as follows:
#
# Topic 10: This topic is dominated by discussions around the cartels themselves, with mentions of 'state', 'whereas', 'united', and 'drug', suggesting a focus on the broader implications of drug trafficking for the United States.
#
# Topic 2: This topic appears to highlight the relationship between the United States and Mexico, with keywords like 'state', 'united', 'whereas', 'mexico', and 'drug', indicating a geopolitical focus in the discourse.
#
# Topic 19: Represented heavily in the sessions, this topic seems to concern border security, as evidenced by words such as 'state', 'border', 'united', 'shall', and 'security', pointing to a legislative and enforcement-centric conversation.
#
# Topic 16: The presence of words like 'mr', 'cartel', 'state', 'committee', and 'organization' suggests a topic centered on the organizational aspects of cartels and their recognition or designation within legislative discussions.
#
# Topic 3: This topic encompasses a transnational perspective on cartels, with 'section', 'state', 'cartel', 'transnational', and 'united' suggesting the discussion of legislation that addresses cross-border criminal activity.
# The distribution of these topics across documents, as visualized in the heatmap, showcases the varying degrees to which each topic permeates the legislative discourse. Notably, some documents are almost entirely dedicated to a single topic, indicating sessions with a focused discussion on specific aspects of the drug trafficking issue.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Interpretation of Visualizations:
#
# The word cloud above provides a visual representation of the frequency of terms in the dataset, with larger-sized words indicating higher frequency. Prominent terms such as "United States," "Security," and "Assistance" suggest a significant emphasis on national security and aid-related discourse, possibly reflecting a multifaceted approach to tackling drug trafficking.
#
# The heatmaps below of word frequencies across documents reveals the specific focus areas within individual transcripts. Higher frequency words, such as "cartel" and "border," reaffirm the emphasis on security and law enforcement. In contrast, the occurrence of terms like "fentanyl" and "corruption" highlights the concern over the public health impact of drug trafficking and the corruption that enables it.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Discussion**
#
# This study embarked on a comprehensive analysis of U.S. congressional discourse concerning Mexican cartel drug trafficking, employing both sentiment analysis and topic modeling to decipher the nuances of legislative discussions. The dual approach provides a multidimensional view of the congressional narrative, revealing how the tone and focus of discussions have evolved over time.
#
# Integration of Sentiment Analysis and Topic Modeling:
#
# The sentiment analysis indicated a narrative shift in congressional discourse from predominantly negative to more positive tones in recent years. This change could reflect a broader trend in policy-making, potentially signaling a move towards a more holistic approach that transcends strict law enforcement measures. In support of this, the topic modeling uncovered an increased prevalence of discussions around public health issues, particularly the mention of specific drugs like "fentanyl," which suggests heightened legislative attention to the public health impact of drug trafficking.
#
# However, the results also highlight a persistent emphasis on crime and security, with terms such as "cartel," "border," and "corruption" frequently surfacing in the analysis. The prominence of security-related topics indicates that, despite the rise in positive sentiment and the inclusion of public health narratives, the security dimension remains a central pillar of congressional dialogue.
#
# Evaluation of the Hypothesis:
#
# The findings lend partial support to the hypothesis that congressional discourse has transitioned towards an integrated approach encompassing public health and socioeconomic considerations. The sentiment analysis suggests a positive turn that could be indicative of discussions that not only address immediate security concerns but also consider the broader implications of drug trafficking on public health and society.
#
# Concurrently, the topic modeling outcomes reveal that while there is a growing legislative consciousness around public health, as denoted by the dialogue on "fentanyl," the anticipated integration of socioeconomic factors into the discourse is not yet fully realized. The focus remains largely on traditional security and law enforcement narratives, and the anticipated pivot towards socioeconomic discourse appears to be in its early stages.
#
# Implications for Policy and Future Research:
#
# The observed shift in sentiment and the emergence of public health discussions within congressional discourse point to potential changes in policy direction. It may suggest a legislative intent to adopt more comprehensive strategies that address the root causes and broader impacts of drug trafficking.
#
# For future research, a qualitative analysis could provide deeper insights into how socioeconomic considerations are woven into the discourse and to what extent they influence policy-making. This would be crucial to confirm whether the discourse truly reflects a significant policy shift or if the inclusion of public health narratives is still peripheral.

# %% [markdown]
# ## **Conclusion:**
# The "Policy Patterns" investigation has meticulously traced the contours of U.S. congressional dialogue concerning the complex issue of Mexican cartel drug trafficking. Through sentiment analysis and topic modeling, the study has provided a quantitative backdrop to the qualitative shifts perceived within legislative sessions. These methods have painted a picture of a discourse that, while still heavily anchored in security and law enforcement rhetoric, shows signs of an emerging, if not entirely realized, sensitivity to public health narratives.
#
# Our findings resonate with the hypothesis that congressional discussions have begun to incorporate a broader array of concerns, extending beyond stringent law enforcement to touch upon public health and socioeconomic factors. The sentiment analysis reflected a notable uptick in positive sentiment in recent years, potentially indicative of a diversifying discourse. Topic modeling also corroborated the presence of public health dialogue, especially concerning the opioid crisis and substances like "fentanyl."
#
# However, the research fell short of conclusively proving a comprehensive shift to an integrated policy approach, as posited in the initial hypothesis. The persistent prevalence of security-related discussions within the transcripts suggests that the transition towards incorporating socioeconomic considerations into the policy debate is still underway and not yet a dominant feature of the discourse.
#
# The limitations of this study—reliance on available transcripts, the scope of the data, and the constraints of quantitative methods—point to areas for further research. Qualitative analyses, perhaps through interviews or policy outcome assessments, could provide the depth needed to fully understand the implications of the identified discourse trends.
#
# In conclusion, while the hypothesis that U.S. congressional discourse is evolving towards a more integrated approach holds water, the current study has illuminated the complexity of this transition. It is evident that the pivot towards a holistic policy framework that equally weighs law enforcement, public health, and socioeconomic strategies is still in progress, marking an area ripe for continued exploration.

# %% [markdown]
# ## **Entire CODE**

# %% [markdown]
# It was a lot easier to imports the drive module from the google.colab and save the URL's I was using into a csv file. I needed import requests to  request data from web pages.
# from bs4 import BeautifulSoup was very useful because i only used XML documents.
#
# The import os provides a way of using operating system-dependent functionality. It can be used to interact with the file system (like reading and writing files), handle paths, and interact with environment variables.

# %%
from google.colab import drive
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os


# Mount your Google Drive
drive.mount('/content/drive')

# List of URLs to extract data from
urls = [   #2023-2024

           'https://www.congress.gov/118/bills/hjres95/BILLS-118hjres95ih.xml', #1
           'https://www.congress.gov/118/bills/sres97/BILLS-118sres97is.xml', #2
           'https://www.congress.gov/118/bills/hr3205/BILLS-118hr3205ih.xml', #3
           'https://www.congress.gov/118/bills/hr776/BILLS-118hr776ih.xml', #4
           'https://www.congress.gov/118/bills/hr163/BILLS-118hr163ih.xml', #5
           'https://www.congress.gov/118/bills/hres830/BILLS-118hres830ih.xml', #6

           #2021 - 2022
           'https://www.congress.gov/117/bills/hr2600/BILLS-117hr2600ih.xml', #1
           'https://www.congress.gov/117/bills/hr812/BILLS-117hr812ih.xml', #2
           'https://www.congress.gov/117/bills/hr9312/BILLS-117hr9312ih.xml', #3
           'https://www.congress.gov/117/bills/sres704/BILLS-117sres704is.xml', #4


           #2019 - 2020
           'https://www.congress.gov/116/bills/s293/BILLS-116s293is.xml', #1
           'https://www.congress.gov/116/bills/hr1700/BILLS-116hr1700ih.xml', #2
           'https://www.congress.gov/116/bills/sres444/BILLS-116sres444is.xml', #3
           'https://www.congress.gov/116/bills/hr416/BILLS-116hr416ih.xml', #4
           'https://www.congress.gov/116/bills/s4612/BILLS-116s4612es.xml', #5

           #2011 - 2012
           'https://www.congress.gov/112/bills/hr4303/BILLS-112hr4303ih.xml', #1
           'https://www.congress.gov/112/bills/hr1270/BILLS-112hr1270ih.xml', #2
           'https://www.congress.gov/112/bills/hr6280/BILLS-112hr6280ih.xml', #3
           'https://www.congress.gov/112/bills/hr77/BILLS-112hr77ih.xml', #4
           'https://www.congress.gov/112/bills/hr77/BILLS-112hr77ih.xml', #5
           'https://www.congress.gov/112/bills/hr915/BILLS-112hr915enr.xml', #6

           #2009 - 2010
           'https://www.congress.gov/111/bills/hres1032/BILLS-111hres1032eh.xml', #1
           'https://www.congress.gov/111/bills/hres1540/BILLS-111hres1540eh.xml', #2
           'https://www.congress.gov/111/bills/hr1900/BILLS-111hr1900ih.xml', #3
           'https://www.congress.gov/111/bills/hr2134/BILLS-111hr2134rfs.xml', #4



           #2007 - 2008
           'https://www.congress.gov/110/bills/hconres369/BILLS-110hconres369eh.xml', #1
           'https://www.congress.gov/110/bills/sres610/BILLS-110sres610ats.xml', #2
           'https://www.congress.gov/110/bills/hr2642/BILLS-110hr2642eah2.xml', #3
           'https://www.congress.gov/110/bills/s3293/BILLS-110s3293is.xml', #4



            ]

# create list
transcripts_data = []

# I was having issues with my for loop so I used chat GPT to help me creat the code below.
#I kept the comments to remeber what the lines do.https://chat.openai.com/share/c0a280ee-00f1-45e7-856a-fe329c3892ef
# Loop through each URL
for url in urls:
    # Send a request to the URL
    response = requests.get(url)
    response.raise_for_status()  # Raise an error if the request failed

    # Parse the content based on the content type
    if url.endswith('.xml'):
        # Parse the XML content
        soup = BeautifulSoup(response.content, 'lxml-xml')  # Use 'lxml-xml' parser for XML content
        texts = soup.get_text(separator=' ', strip=True)
    else:
        # Parse the HTML content
        soup = BeautifulSoup(response.text, 'html.parser')
        texts = soup.get_text(separator=' ', strip=True)

    # Append the full text of the transcript to the list
    transcripts_data.append({'URL': url, 'Text': texts})

# Convert the list of dictionaries to a DataFrame
transcripts_df = pd.DataFrame(transcripts_data)

# Define the path to the folder where you want to save the file on your Google Drive
folder_path = '/content/drive/MyDrive/SIPA Fall 2023/INAF 6502/Project'  # Adjust the path to your needs

# Check if the folder exists and create it if it doesn't
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# Save the DataFrame as a CSV file in the Google Drive folder
csv_file = os.path.join(folder_path, 'transcripts_2.csv')
transcripts_df.to_csv(csv_file, index=False)

print(f'Data saved to {csv_file}')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Data saved to /content/drive/MyDrive/SIPA Fall 2023/INAF 6502/Project/transcripts_2.csv

# %%
transcripts_df = pd.read_csv("/content/drive/MyDrive/SIPA Fall 2023/INAF 6502/Project/transcripts_2.csv", delimiter=',', encoding='utf-8')
transcripts_df.head(5)  # Display the first few rows of the dataframe
# Out:
#                                                  URL  \
# 0  https://www.congress.gov/118/bills/hjres95/BIL...
# 1  https://www.congress.gov/118/bills/sres97/BILL...
# 2  https://www.congress.gov/118/bills/hr3205/BILL...
# 3  https://www.congress.gov/118/bills/hr776/BILLS...
# 4  https://www.congress.gov/118/bills/hr163/BILLS...
#
#                                                 Text
# 0  118 HJ 95 IH: Declaring a state of war between...
# 1  118 SRES 97 IS: Expressing concern about econo...
# 2  118 HR 3205 IH: Project Precursor Act U.S. Hou...
# 3  118 HR 776 IH: Build up Illegal Line Defenses ...
# 4  118 HR 163 IH: Security First Act U.S. House o...

# %%
transcripts_df.columns
# Out:
# Index(['URL', 'Text'], dtype='object')

# %% [markdown]
# ## **I wanted to add a Column called 'DATE' in order to make the graph for sentiment over time make sense, thus creating the following code.**

# %%
import re

# Function to extract the Congress number from a URL
def extract_congress_from_url(url):
    match = re.search(r'/(\d+)/bills/', url)
    return int(match.group(1)) if match else None

# I used Dictionary mapping Congress numbers to approximate date ranges
congress_dates = {

    114: '2015-2016',
    117: '2021-2022',
    118: '2023-2024',
    116: '2019-2020',
    112: '2011-2012',
    111: '2009-2010',
    110: '2007-2008',
}

# Extracting Congress number and adding the date range
transcripts_df['Congress'] = transcripts_df['URL'].apply(extract_congress_from_url)
transcripts_df['Date'] = transcripts_df['Congress'].map(congress_dates)

# Display the updated DataFrame
print(transcripts_df.head(20))
# Out:
#                                                   URL  \
# 0   https://www.congress.gov/118/bills/hjres95/BIL...
# 1   https://www.congress.gov/118/bills/sres97/BILL...
# 2   https://www.congress.gov/118/bills/hr3205/BILL...
# 3   https://www.congress.gov/118/bills/hr776/BILLS...
# 4   https://www.congress.gov/118/bills/hr163/BILLS...
# 5   https://www.congress.gov/118/bills/hres830/BIL...
# 6   https://www.congress.gov/117/bills/hr2600/BILL...
# 7   https://www.congress.gov/117/bills/hr812/BILLS...
# 8   https://www.congress.gov/117/bills/hr9312/BILL...
# 9   https://www.congress.gov/117/bills/sres704/BIL...
# 10  https://www.congress.gov/116/bills/s293/BILLS-...
# 11  https://www.congress.gov/116/bills/hr1700/BILL...
# 12  https://www.congress.gov/116/bills/sres444/BIL...
# 13  https://www.congress.gov/116/bills/hr416/BILLS...
# 14  https://www.congress.gov/116/bills/s4612/BILLS...
# 15  https://www.congress.gov/112/bills/hr4303/BILL...
# ...

# %%
print(transcripts_df.isnull().sum())
# This will show the count of null values in each column.
#There are none so no need to remove any.
# Out:
# URL                0
# Text               0
# Congress           0
# Date               0
# sentiment_score    0
# Year               0
# dtype: int64

# %% [markdown]
# ## **Sentiment Analysis**

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
# Apply the Sentiment Intensity Analyzer to the 'Text' column
transcripts_df['sentiment_score'] = transcripts_df['Text'].apply(lambda text: sia.polarity_scores(text)['compound'])
#Durring my computing in context class(INAF 6006) I used this same code on a HW assignment. I used the same code
#and adjusted accordingly.
# Display the DataFrame to see the sentiment scores
print(transcripts_df[['URL', 'sentiment_score']].head(20))

# (Optional) Further analysis or visualization
# Out:
#                                                   URL  sentiment_score
# 0   https://www.congress.gov/118/bills/hjres95/BIL...          -0.9805
# 1   https://www.congress.gov/118/bills/sres97/BILL...           0.9985
# 2   https://www.congress.gov/118/bills/hr3205/BILL...           0.9990
# 3   https://www.congress.gov/118/bills/hr776/BILLS...           0.5248
# 4   https://www.congress.gov/118/bills/hr163/BILLS...           0.9985
# 5   https://www.congress.gov/118/bills/hres830/BIL...          -0.7579
# 6   https://www.congress.gov/117/bills/hr2600/BILL...          -0.6858
# 7   https://www.congress.gov/117/bills/hr812/BILLS...           0.9985
# 8   https://www.congress.gov/117/bills/hr9312/BILL...          -0.9993
# 9   https://www.congress.gov/117/bills/sres704/BIL...           0.9985
# 10  https://www.congress.gov/116/bills/s293/BILLS-...           0.9992
# 11  https://www.congress.gov/116/bills/hr1700/BILL...           0.0129
# ...

# %%
#Start year from the 'Date' range and create a 'Year' column
transcripts_df['Year'] = transcripts_df['Date'].str.extract(r'(\d{4})').astype(int)

# Group by 'Year' and calculate the average sentiment
sentiment_over_time = transcripts_df.groupby('Year')['sentiment_score'].mean()

# Plotting
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sentiment_over_time.plot(kind='line', title='Average Sentiment Over Time')
plt.xlabel('Year')
plt.ylabel('Average Sentiment Score')
plt.show()

# I used the following link to create this grapgh: https://www.learndatasci.com/tutorials/sentiment-analysis-reddit-headlines-pythons-nltk/

# %%
print(sentiment_over_time.head(7))
#Here I was checking to see some numerical value to see if it worked.
# Out:
# Year
# 2007    0.490225
# 2009    0.315775
# 2011    0.334467
# 2019   -0.061900
# 2021    0.077975
# 2023    0.297067
# Name: sentiment_score, dtype: float64

# %%
print(sentiment_over_time.describe())
#Here I used describe to see if the mean or max may have seem odd.
# Out:
# count    6.000000
# mean     0.242268
# std      0.198947
# min     -0.061900
# 25%      0.132748
# 50%      0.306421
# 75%      0.329794
# max      0.490225
# Name: sentiment_score, dtype: float64

# %%
import matplotlib.pyplot as plt

# Plotting the histogram of sentiment scores from transcripts_df
transcripts_df['sentiment_score'].plot(kind='hist', title='Sentiment Score Distribution')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## **Topic Modeling**

# %%
#I was having issues here so i decided to use chat GPT again to at least get the frame work.
#https://chat.openai.com/share/c0a280ee-00f1-45e7-856a-fe329c3892ef
import gensim
from gensim import corpora
from gensim.models.ldamodel import LdaModel
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import string
import nltk
nltk.download('stopwords')
nltk.download('wordnet')


# Preprocess documents
stop = set(stopwords.words('english'))
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()

def clean(doc):
    stop_free = " ".join([word for word in doc.lower().split() if word not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

# Cleaning the text in the 'Text' column
transcripts_df['Cleaned_Text'] = transcripts_df['Text'].apply(clean)

# Tokenize the cleaned text
transcripts_df['Tokenized_Text'] = transcripts_df['Cleaned_Text'].apply(lambda x: x.split())

# Create a dictionary and corpus needed for Topic Modeling
dictionary = corpora.Dictionary(transcripts_df['Tokenized_Text'])
corpus = [dictionary.doc2bow(text) for text in transcripts_df['Tokenized_Text']]

# Build LDA model
ldamodel = LdaModel(corpus=corpus, num_topics=20, id2word=dictionary, passes=15)

# Print topics and words associated with each topic
topics = ldamodel.print_topics(num_words=5)
for topic in topics:
    print(topic)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# (0, '0.027*"united" + 0.027*"state" + 0.022*"mexico" + 0.018*"whereas" + 0.016*"drug"')
# (1, '0.028*"border" + 0.026*"enforcement" + 0.022*"best" + 0.021*"state" + 0.018*"security"')
# (2, '0.024*"state" + 0.023*"united" + 0.021*"whereas" + 0.017*"mexico" + 0.010*"drug"')
# (3, '0.028*"section" + 0.023*"state" + 0.022*"cartel" + 0.021*"transnational" + 0.020*"united"')
# (4, '0.000*"state" + 0.000*"united" + 0.000*"shall" + 0.000*"border" + 0.000*"mexico"')
# (5, '0.019*"section" + 0.019*"shall" + 0.017*"assistance" + 0.016*"state" + 0.013*"amount"')
# (6, '0.001*"section" + 0.001*"shall" + 0.000*"state" + 0.000*"available" + 0.000*"assistance"')
# (7, '0.000*"shall" + 0.000*"state" + 0.000*"border" + 0.000*"a" + 0.000*"secretary"')
# ...

# %%
#This is a continuation of the previous code from the same chat gpt thread. https://chat.openai.com/share/c0a280ee-00f1-45e7-856a-fe329c3892ef
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=transcripts_df['Tokenized_Text']):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = sorted(row_list, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  #  dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                new_row = pd.Series([int(topic_num), round(prop_topic, 4), topic_keywords])
                sent_topics_df = pd.concat([sent_topics_df, new_row.to_frame().T], ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents.rename('Text')], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamodel, corpus=corpus, texts=transcripts_df['Text'])

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head(10)
# Out:
#    Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0            0             10             0.9984
# 1            1              2             0.9991
# 2            2             19             0.7629
# 3            3             16             0.9967
# 4            4             19              0.999
# 5            5              2             0.9972
# 6            6             16             0.9978
# 7            7             19             0.9971
# 8            8              3             0.9993
# 9            9              2             0.9991
#
#                                             Keywords  \
# 0  cartel, state, whereas, united, drug, methamph...
# 1  state, united, whereas, mexico, drug, dea, fen...
# 2  state, border, united, shall, security, drug, ...
# 3  mr, cartel, state, committee, organization, fo...
# 4  state, border, united, shall, security, drug, ...
# 5  state, united, whereas, mexico, drug, dea, fen...
# ...

# %% [markdown]
# From the code right above I saw on the side a suggest chart option from google colab. I thought it was interesting so clicked one and got the following code. This chart is very useful, but I also continued with what I wanted to do originally. This gave google colab a huge plus in my book for future projects.

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Keywords'].value_counts()
    for x_label, grp in _df_6.groupby('Dominant_Topic')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Dominant_Topic')
_ = plt.ylabel('Keywords')

# %% [markdown]
# # **Word cloud**

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

all_text = ' '.join(text for text in df_dominant_topic['Text'])

# Generate the word cloud
wordcloud = WordCloud(width = 800, height = 800,
                      background_color ='white',
                      min_font_size = 10).generate(all_text)

# Display the word cloud
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()
# word clouds were pretty easy, i used this link to create my code: https://www.geeksforgeeks.org/generating-word-cloud-python/

# %% [markdown]
# These words were not exactly what I was looking for so I did another attempt, but this time removing stopwords.

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import nltk

# Download the set of stop words from NLTK
nltk.download('stopwords')
from nltk.corpus import stopwords

# Combine all text data into a single string
all_text = ' '.join(text for text in df_dominant_topic['Text'])

# Create a list of words to exclude
stopwords = set(STOPWORDS)
custom_stopwords = ['section', 'title', 'including', 'may', 'act', 'paragraph', 'subsection' ]  # Add other words you wish to exclude

# Update the stopwords set with your custom stopwords
stopwords.update(custom_stopwords)

# Generate the word cloud with the updated stopwords
wordcloud = WordCloud(width=800, height=800,
                      background_color='white',
                      stopwords=stopwords,
                      min_word_length=5,  # Exclude words with length less than 5 characters
                      min_font_size=10).generate(all_text)

# Display the word cloud
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()
#used this same link for this code: https://www.geeksforgeeks.org/generating-word-cloud-python/
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from sklearn.feature_extraction.text import CountVectorizer
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# The words of interest
words_of_interest = ["cartel", "sinaloa", "cjng", "traffic", "violence", "brutal", "fentanyl", "cocaine",
                     "heroin", "corruption",
                     'border', 'drug', 'gun', 'terrorist']

# Using CountVectorizer to find the frequency of the words of interest in each document
# Replace 'transcripts_df.iloc[:, 5]' with the actual reference to your column
vectorizer = CountVectorizer(vocabulary=words_of_interest)
word_matrix = vectorizer.fit_transform(df_dominant_topic.iloc[:, 4]).toarray()

# Create a DataFrame with the word frequencies
word_freq_df = pd.DataFrame(word_matrix, columns=vectorizer.get_feature_names_out())

# Create a heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(word_freq_df, cmap='viridis', annot=True, annot_kws={"size": 8})
plt.title('Heatmap of Word Frequencies Across Documents')
plt.xlabel('Words')
plt.ylabel('Document Number')
plt.xticks(rotation=45, ha='right')  # Rotate x labels for better readability
plt.tight_layout()  # Adjust layout to fit everything
plt.show()

# I used the following to help me create my code:
#https://github.com/rskrisel/tf-idf/blob/main/TF-IDF-with-Scikit-Learn.ipynb
#https://melaniewalsh.github.io/Intro-Cultural-Analytics/05-Text-Analysis/03-TF-IDF-Scikit-Learn.html

# %% [markdown]
# For the code above I used the topic modeling workshop to create the heat map and suggestions form my other python class to use  https://colab.research.google.com/drive/1MNMQQq2GrVCQL6Cd-HdTv5xmkz8HiktT#scrollTo=YfeimjEN0uj3
#
# When I could get the code to work i used chat gpt to fix my code.

# %%
print(df_dominant_topic.head())
# Out:
#    Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0            0             10             0.9984
# 1            1              2             0.9991
# 2            2             19             0.7629
# 3            3             16             0.9967
# 4            4             19             0.9989
#
#                                             Keywords  \
# 0  cartel, state, whereas, united, drug, methamph...
# 1  state, united, whereas, mexico, drug, dea, fen...
# 2  state, border, united, shall, security, drug, ...
# 3  mr, cartel, state, committee, organization, fo...
# 4  state, border, united, shall, security, drug, ...
#
#                                                 Text
# 0  118 HJ 95 IH: Declaring a state of war between...
# 1  118 SRES 97 IS: Expressing concern about econo...
# 2  118 HR 3205 IH: Project Precursor Act U.S. Hou...
# 3  118 HR 776 IH: Build up Illegal Line Defenses ...
# 4  118 HR 163 IH: Security First Act U.S. House o...
